# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw_data = pd.read_csv('winequality-red.csv')

# %%
raw_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
raw_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
raw_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
correlations = raw_data.corr()['quality'].drop('quality')
print(correlations)
# Out:
# fixed acidity           0.124052
# volatile acidity       -0.390558
# citric acid             0.226373
# residual sugar          0.013732
# chlorides              -0.128907
# free sulfur dioxide    -0.050656
# total sulfur dioxide   -0.185100
# density                -0.174919
# pH                     -0.057731
# sulphates               0.251397
# alcohol                 0.476166
# Name: quality, dtype: float64

# %%
sns.heatmap(raw_data.corr())
mlb.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-5ab0c8007ac7> in <module>
#       1 sns.heatmap(raw_data.corr())
# ----> 2 mlb.show()
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
from scipy.stats import pearsonr

# %%
y = raw_data['quality']

# %%
x = raw_data[raw_data.columns[:-1]]

# %%
x.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
corrs = pearsonr(x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-077534ccb961> in <module>
# ----> 1 corrs = pearsonr(x, y)
#
# ~/.virtualenvs/ml/lib/python3.6/site-packages/scipy/stats/stats.py in pearsonr(x, y)
#    3006     my = y.mean()
#    3007     xm, ym = x - mx, y - my
# -> 3008     r_num = np.add.reduce(xm * ym)
#    3009     r_den = np.sqrt(_sum_of_squares(xm) * _sum_of_squares(ym))
#    3010     r = r_num / r_den
#
# ValueError: operands could not be broadcast together with shapes (1599,11) (1599,)

# %%
from collections import defaultdict

# %%
corrs = [(col, pearsonr(x[col],y)) for col in x.columns]
corrs = pd.DataFrame(index = [ind[0] for ind in corrs], data={
        'corr_coef': [corr[1][0] for corr in corrs],
        'p_value': [corr[1][1] for corr in corrs],
    })

# %%
corrs
# Out:
#                       corr_coef       p_value
# fixed acidity          0.124052  6.495635e-07
# volatile acidity      -0.390558  2.051715e-59
# citric acid            0.226373  4.991295e-20
# residual sugar         0.013732  5.832180e-01
# chlorides             -0.128907  2.313383e-07
# free sulfur dioxide   -0.050656  4.283398e-02
# total sulfur dioxide  -0.185100  8.621703e-14
# density               -0.174919  1.874957e-12
# pH                    -0.057731  2.096278e-02
# sulphates              0.251397  1.802088e-24
# alcohol                0.476166  2.831477e-91

# %%
pd.plotting.scatter_matrix(raw_data
                           , figsize = (40,40), diagonal = 'kde');

# %%
fig, axs = plt.subplots(ncols=1,figsize=(10,6))
sns.barplot(x='quality', y='volatile acidity', data=raw_data, ax=axs)
plt.title('quality VS volatile acidity')

plt.tight_layout()
plt.show()
# Out:
# /Users/joliechu/.virtualenvs/ml/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.countplot(y)
plt.show()

# %%
from tukey_outliers_helper import TukeyOutliersHelper
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-56-a20948b1b0b0> in <module>
# ----> 1 from tukey_outliers_helper import TukeyOutliersHelper
#
# ModuleNotFoundError: No module named 'tukey_outliers_helper'

# %%
from scipy import stats
idx = np.all(stats.zscore(x) < 3, axis=1)

# %%
sum(x == False for x in idx )
# Out:
# 136

# %%
len(idx)
# Out:
# 1599

# %%
sum(x == True for x in idx )
# Out:
# 1463

# %%
clean_data = pd.concat([x.loc[idx],y.loc[idx]],axis=1)

# %%
clean_x = clean_data[clean_data.columns[:-1]]
clean_y = clean_data['quality']

# %%
sns.countplot(clean_y)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score

from xgboost.sklearn import XGBClassifier

# %%
X_train, X_test, Y_train, Y_test = train_test_split(clean_x, clean_x, test_size=0.33, random_state=4)

# %%
xg = XGBClassifier()
print('XGBoost: {}'.format(np.mean(cross_val_score(xg, clean_x, new_y, cv=10))))
# Out:
# XGBoost: 0.8379818353824697

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
nb = GaussianNB()
print('GaussianNB: {}'.format(np.mean(cross_val_score(nb, clean_x, new_y, cv=10))))
# Out:
# GaussianNB: 0.7914733841550766

# %%
dt = DecisionTreeClassifier()
print('DecisionTreeClassifier: {}'.format(np.mean(cross_val_score(dt, clean_x, clean_y, cv=10))))
# Out:
# DecisionTreeClassifier: 0.4504382510921746
# /Users/joliechu/.virtualenvs/ml/lib/python3.6/site-packages/sklearn/model_selection/_split.py:626: Warning: The least populated class in y has only 7 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)

# %%
rd = RandomForestClassifier()
print('DecisionTreeClassifier: {}'.format(np.mean(cross_val_score(rd, clean_x, clean_y, cv=10))))
# Out:
# /Users/joliechu/.virtualenvs/ml/lib/python3.6/site-packages/sklearn/model_selection/_split.py:626: Warning: The least populated class in y has only 7 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# /Users/joliechu/.virtualenvs/ml/lib/python3.6/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/joliechu/.virtualenvs/ml/lib/python3.6/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/joliechu/.virtualenvs/ml/lib/python3.6/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# ...

# %%
for i in range(2,20):
    knn= KNeighborsClassifier(n_neighbors = i)
    print(str(i)+'KNeighborsClassifier: {}'.format(np.mean(cross_val_score(knn, clean_x, clean_y, cv=10))))
# Out:
# /Users/joliechu/.virtualenvs/ml/lib/python3.6/site-packages/sklearn/model_selection/_split.py:626: Warning: The least populated class in y has only 7 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# /Users/joliechu/.virtualenvs/ml/lib/python3.6/site-packages/sklearn/model_selection/_split.py:626: Warning: The least populated class in y has only 7 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# /Users/joliechu/.virtualenvs/ml/lib/python3.6/site-packages/sklearn/model_selection/_split.py:626: Warning: The least populated class in y has only 7 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# ...

# %%
cross_val_score(xg, x, y, cv=10)
# Out:
# array([0.54320988, 0.58385093, 0.54037267, 0.5125    , 0.55625   ,
#        0.65625   , 0.59375   , 0.54375   , 0.63291139, 0.50955414])

# %%
logreg = LogisticRegression(solver='lbfgs', max_iter=10000)
print('LogisticRegression: {}'.format(np.mean(cross_val_score(logreg, clean_x, new_y, cv=10))))
# Out:
# /Users/joliechu/.virtualenvs/ml/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:459: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/joliechu/.virtualenvs/ml/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:459: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/joliechu/.virtualenvs/ml/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:459: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# ...

# %%
from sklearn.model_selection import GridSearchCV
parameters = dict(     
    learning_rate= [0.18,0.185],
    n_estimators = [50, 100, 150],
    max_depth = [2, 4, 6, 8],
    subsample=[0.8, 0.9, 1],
)   

CV = GridSearchCV(xg, parameters, scoring='accuracy', cv=10)
CV.fit(clean_x, clean_y)   
print(CV.best_params_)    
print(CV.best_score_)
# Out:
# /Users/joliechu/.virtualenvs/ml/lib/python3.6/site-packages/sklearn/model_selection/_split.py:626: Warning: The least populated class in y has only 7 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# {'learning_rate': 0.185, 'max_depth': 2, 'n_estimators': 50, 'subsample': 0.9}
# 0.5871496924128503
# /Users/joliechu/.virtualenvs/ml/lib/python3.6/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
plot_importance(CV.best_estimator_, max_num_features=10, height=0.5)

# %%
from xgboost import plot_importance,plot_tree

# %%
print classification_report(y_true=yy_test, y_pred=ensemble_preds)

# %%
clean_y.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %%
bins = [1,4,6,10]

#0 for low quality, 1 for average, 2 for great quality
quality_labels=[0,1,2]
new_y = pd.cut(clean_y, bins=bins, labels=quality_labels, include_lowest=True)

# %%
# Out:
# count     1463
# unique       3
# top          1
# freq      1206
# Name: quality, dtype: int64
